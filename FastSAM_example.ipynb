# %%
# !git clone https://github.com/CASIA-IVA-Lab/FastSAM.git

# %%
# !wget -P FastSAM/weights https://huggingface.co/spaces/An-619/FastSAM/resolve/main/weights/FastSAM.pt
# Out:
# --2023-11-21 00:17:31--  https://huggingface.co/spaces/An-619/FastSAM/resolve/main/weights/FastSAM.pt
# Resolving huggingface.co (huggingface.co)... 18.238.49.10, 18.238.49.117, 18.238.49.70, ...
# Connecting to huggingface.co (huggingface.co)|18.238.49.10|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !pip install -r FastSAM/requirements.txt
# !pip install git+https://github.com/openai/CLIP.git

# %%
# !wget -P images https://raw.githubusercontent.com/facebookresearch/segment-anything/main/notebooks/images/dog.jpg

# %%
import matplotlib.pyplot as plt
import cv2

# %%
image = cv2.imread('resources/images/dog.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
original_h = image.shape[0]
original_w = image.shape[1]
print(original_w, original_h)
plt.figure(figsize=(10, 10))
plt.imshow(image)
# Out:
# 800 534

# %% [markdown]
# "--imgsz 1024" means the input image size is 1024. Our model was trained on a size of 1024. You can change it to any size you want to input. Using other sizes would produce different segmentation results.

# %%
# !python FastSAM/Inference.py  --model_path FastSAM/weights/FastSAM.pt --img_path resources/images/dog.jpg --imgsz 1024
# Out:
# 0: 704x1024 35 objects, 187.2ms
# Speed: 3.4ms preprocess, 187.2ms inference, 512.2ms postprocess per image at shape (1, 3, 1024, 1024)

# %%
image = cv2.imread('resources/output/dog.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
original_h = image.shape[0]
original_w = image.shape[1]
print(original_w, original_h)
plt.figure(figsize=(10, 10))
plt.axis("off")
plt.imshow(image)
# Out:
# 800 534

# %%
# !git clone https://github.com/CASIA-IVA-Lab/FastSAM.git

# %%
# !wget https://huggingface.co/spaces/An-619/FastSAM/resolve/main/weights/FastSAM.pt
# Out:
# --2023-11-20 16:49:24--  https://huggingface.co/spaces/An-619/FastSAM/resolve/main/weights/FastSAM.pt
# Resolving huggingface.co (huggingface.co)... 18.238.49.10, 18.238.49.117, 18.238.49.112, ...
# Connecting to huggingface.co (huggingface.co)|18.238.49.10|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/71/c3/71c3ec5a83f3fc374665cec9240f614262e29088fca1a18732571e13c7084f1b/c0be4e7ddbe4c15333d15a859c676d053c486d0a746a3be6a7a9790d52a9b6d7?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27FastSAM.pt%3B+filename%3D%22FastSAM.pt%22%3B&Expires=1700776164&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=JfsROLSGAraIgKY%7EYJA5EuREPl%7E1eWj-PxSwHBCBBBkZk143BiMY7a0fac9rneFibKGAu7zZ7Qss4lY9qIvQ843DQZpBDMBtryUiVtRI1Ep6%7Ekx6bvZ6XAW0iX86%7EW26VlHDuNqf4dK-6jTWtoMTYKTHGDK%7Eral-HNs-KNR6RrVMVJ8OZEZf4lELsmijhAWugLlHZkC%7Eeqhr8VIN2TKhHwM%7E9nnpzuFHNjoqhty3gVobafsaGwI8HEtTBN5q6lQESQ7Iv7anaIDX8rhebdvvsbtRQ60N6qVu1zFJc3G4kTO7Q%7EaabEv2r9yKmUSAe2WBmBgZmHKMvb0m3X4dCiT35w__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2023-11-20 16:49:24--  https://cdn-lfs.huggingface.co/repos/71/c3/71c3ec5a83f3fc374665cec9240f614262e29088fca1a18732571e13c7084f1b/c0be4e7ddbe4c15333d15a859c676d053c486d0a746a3be6a7a9790d52a9b6d7?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27FastSAM.pt%3B+filename%3D%22FastSAM.pt%22%3B&Expires=1700776164&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=JfsROLSGAraIgKY%7EYJA5EuREPl%7E1eWj-PxSwHBCBBBkZk143BiMY7a0fac9rneFibKGAu7zZ7Qss4lY9qIvQ843DQZpBDMBtryUiVtRI1Ep6%7Ekx6bvZ6XAW0iX86%7EW26VlHDuNqf4dK-6jTWtoMTYKTHGDK%7Eral-HNs-KNR6RrVMVJ8OZEZf4lELsmijhAWugLlHZkC%7Eeqhr8VIN2TKhHwM%7E9nnpzuFHNjoqhty3gVobafsaGwI8HEtTBN5q6lQESQ7Iv7anaIDX8rhebdvvsbtRQ60N6qVu1zFJc3G4kTO7Q%7EaabEv2r9yKmUSAe2WBmBgZmHKMvb0m3X4dCiT35w__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 18.164.116.66, 18.164.116.111, 18.164.116.15, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|18.164.116.66|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 144943063 (138M) [application/zip]
# Saving to: ‘FastSAM.pt’
#
# FastSAM.pt          100%[===================>] 138.23M  5.21MB/s    in 30s
#
# 2023-11-20 16:49:55 (4.59 MB/s) - ‘FastSAM.pt’ saved [144943063/144943063]

# %%
# !pip install -r FastSAM/requirements.txt
# !pip install git+https://github.com/openai/CLIP.git

# %%
# !wget -P images https://raw.githubusercontent.com/facebookresearch/segment-anything/main/notebooks/images/dog.jpg

# %%
import matplotlib.pyplot as plt
import cv2

# %%
image = cv2.imread('images/dog.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
original_h = image.shape[0]
original_w = image.shape[1]
print(original_w, original_h)
plt.figure(figsize=(10, 10))
plt.imshow(image)
# Out:
# 800 534

# %% [markdown]
# "--imgsz 1024" means the input image size is 1024. Our model was trained on a size of 1024. You can change it to any size you want to input. Using other sizes would produce different segmentation results.

# %%
# !python FastSAM/Inference.py  --model_path FastSAM.pt --img_path ./images/dog.jpg --imgsz 1024
# Out:
# 0: 704x1024 35 objects, 186.9ms
# Speed: 264.7ms preprocess, 186.9ms inference, 525.4ms postprocess per image at shape (1, 3, 1024, 1024)

# %%
image = cv2.imread('output/dog.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
original_h = image.shape[0]
original_w = image.shape[1]
print(original_w, original_h)
plt.figure(figsize=(10, 10))
plt.axis("off")
plt.imshow(image)
# Out:
# 800 534
